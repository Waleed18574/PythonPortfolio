# %% [markdown]
# # World Bank Poverty and Equity Data Analysis and Visualization

# %% [markdown]
# ## Libraries Importing

# %%
import os
import pandas as pd
pd.options.display.max_columns = None
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
from dash.exceptions import PreventUpdate
import plotly
import dash
import plotly.graph_objects as go
import re

# %% [markdown]
# ## Data Collection & Preparation

# %%
poverty = pd.read_csv('../data/poverty.csv', low_memory=False)
poverty.head(3)
# Out:
#   Country Name Country Code  year  \
# 0  Afghanistan          AFG  1974
# 1  Afghanistan          AFG  1975
# 2  Afghanistan          AFG  1976
#
#    Annualized growth in per capita real survey mean consumption or income, bottom 40% (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Annualized growth in per capita real survey mean consumption or income, top 10% (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Annualized growth in per capita real survey mean consumption or income, top 60% (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Annualized growth in per capita real survey mean consumption or income, total population (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Annualized growth in per capita real survey median income or consumption expenditure (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#    Growth component of change in poverty at $1.90 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Growth component of change in poverty at $3.20 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Growth component of change in poverty at $5.50 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Income share held by fourth 20%  Income share held by highest 10%  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
#
#    Income share held by highest 20%  Income share held by lowest 10%  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
#
#    Income share held by lowest 20%  Income share held by second 20%  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
#
#    Income share held by third 20%  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
#
#    Median daily per capita income or consumption expenditure (2011 PPP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Drinking water (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Educational attainment (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Educational enrollment (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Electricity (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Headcount ratio (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Monetary poverty (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Multidimensional poverty, Sanitation (% of population deprived)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Number of poor at $1.90 a day (2011 PPP) (millions)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Number of poor at $3.20 a day (2011 PPP) (millions)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Number of poor at $5.50 a day (2011 PPP) (millions)  Population, total  \
# 0                                                NaN           12412950.0
# 1                                                NaN           12689160.0
# 2                                                NaN           12943093.0
#
#    Poverty gap at $1.90 a day (2011 PPP) (%)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#    Poverty gap at $3.20 a day (2011 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty gap at $5.50 a day (2011 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, Female (2011 PPP) (% of female population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, Male  (2011 PPP) (% of male population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, age 0-14  (2011 PPP) (% of population age 0-14)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, age 15-64 (2011 PPP) (% of population age 15-64)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, age 65+ (2011 PPP) (% of population age 65+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, rural (2011 PPP) (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, urban (2011 PPP) (% of urban population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, with primary education (2011 PPP) (% of population age 16+ with primary education)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, with secondary education (2011 PPP) (% of population age 16+ with secondary education)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day, without education (2011 PPP) (% of population age 16+ without education)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $1.90 a day,  with Tertiary/post-secondary education (2011 PPP) (% of population age 16+ with Tertiary/post-secondary education)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Poverty headcount ratio at national poverty lines (% of population), including noncomparable values  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Redistribution component of change in poverty at $1.90 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Redistribution component of change in poverty at $3.20 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Redistribution component of change in poverty at $5.50 a day (2011 PPP) (% of change)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Survey mean consumption or income per capita, bottom 40% (2011 PPP $ per day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Survey mean consumption or income per capita, top 10% (2011 PPP $ per day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Survey mean consumption or income per capita, top 60% (2011 PPP $ per day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Survey mean consumption or income per capita, total population (2011 PPP $ per day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#     Short Name   Table Name                     Long Name 2-alpha code  \
# 0  Afghanistan  Afghanistan  Islamic State of Afghanistan           AF
# 1  Afghanistan  Afghanistan  Islamic State of Afghanistan           AF
# 2  Afghanistan  Afghanistan  Islamic State of Afghanistan           AF
#
#     Currency Unit Special Notes      Region Income Group WB-2 code  \
# 0  Afghan afghani           NaN  South Asia   Low income        AF
# 1  Afghan afghani           NaN  South Asia   Low income        AF
# 2  Afghan afghani           NaN  South Asia   Low income        AF
#
#   National accounts base year National accounts reference year  \
# 0                     2002/03                              NaN
# 1                     2002/03                              NaN
# 2                     2002/03                              NaN
#
#                  SNA price valuation Lending category Other groups  \
# 0  Value added at basic prices (VAB)              IDA         HIPC
# 1  Value added at basic prices (VAB)              IDA         HIPC
# 2  Value added at basic prices (VAB)              IDA         HIPC
#
#                          System of National Accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
#
#   Alternative conversion factor PPP survey year  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
#
#   Balance of Payments Manual in use External debt Reporting status  \
# 0                              BPM6                         Actual
# 1                              BPM6                         Actual
# 2                              BPM6                         Actual
#
#         System of trade    Government Accounting concept  \
# 0  General trade system  Consolidated central government
# 1  General trade system  Consolidated central government
# 2  General trade system  Consolidated central government
#
#                      IMF data dissemination standard Latest population census  \
# 0  Enhanced General Data Dissemination System (e-...                     1979
# 1  Enhanced General Data Dissemination System (e-...                     1979
# 2  Enhanced General Data Dissemination System (e-...                     1979
#
#                Latest household survey  \
# 0  Demographic and Health Survey, 2015
# 1  Demographic and Health Survey, 2015
# 2  Demographic and Health Survey, 2015
#
#   Source of most recent Income and expenditure data  \
# 0        Integrated household survey (IHS), 2016/17
# 1        Integrated household survey (IHS), 2016/17
# 2        Integrated household survey (IHS), 2016/17
#
#   Vital registration complete Latest agricultural census  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
#
#    Latest industrial data  Latest trade data  Unnamed: 30  is_country flag
# 0                     NaN             2017.0          NaN        True   🇦🇫
# 1                     NaN             2017.0          NaN        True   🇦🇫
# 2                     NaN             2017.0          NaN        True   🇦🇫

# %%
gini = 'GINI index (World Bank estimate)'
gini_df = poverty[poverty[gini].notna()]
gini_df.head(3)
# Out:
#    Country Name Country Code  year  \
# 67      Albania          ALB  1996
# 73      Albania          ALB  2002
# 76      Albania          ALB  2005
#
#     Annualized growth in per capita real survey mean consumption or income, bottom 40% (%)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Annualized growth in per capita real survey mean consumption or income, top 10% (%)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Annualized growth in per capita real survey mean consumption or income, top 60% (%)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Annualized growth in per capita real survey mean consumption or income, total population (%)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Annualized growth in per capita real survey median income or consumption expenditure (%)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     GINI index (World Bank estimate)  \
# 67                              27.0
# 73                              31.7
# 76                              30.6
#
#     Growth component of change in poverty at $1.90 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Growth component of change in poverty at $3.20 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Growth component of change in poverty at $5.50 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Income share held by fourth 20%  Income share held by highest 10%  \
# 67                             23.3                              21.2
# 73                             22.2                              25.4
# 76                             22.5                              24.3
#
#     Income share held by highest 20%  Income share held by lowest 10%  \
# 67                              36.1                              3.9
# 73                              40.4                              3.5
# 76                              39.2                              3.5
#
#     Income share held by lowest 20%  Income share held by second 20%  \
# 67                              9.2                             13.7
# 73                              8.4                             12.6
# 76                              8.4                             12.9
#
#     Income share held by third 20%  \
# 67                            17.7
# 73                            16.5
# 76                            17.0
#
#     Median daily per capita income or consumption expenditure (2011 PPP)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Drinking water (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Educational attainment (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Educational enrollment (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Electricity (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Headcount ratio (% of population)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Monetary poverty (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Multidimensional poverty, Sanitation (% of population deprived)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Number of poor at $1.90 a day (2011 PPP) (millions)  \
# 67                                                0.0
# 73                                                0.1
# 76                                                0.0
#
#     Number of poor at $3.20 a day (2011 PPP) (millions)  \
# 67                                                0.4
# 73                                                0.5
# 76                                                0.3
#
#     Number of poor at $5.50 a day (2011 PPP) (millions)  Population, total  \
# 67                                                1.6            3168033.0
# 73                                                1.6            3051010.0
# 76                                                1.3            3011487.0
#
#     Poverty gap at $1.90 a day (2011 PPP) (%)  \
# 67                                        0.2
# 73                                        0.4
# 76                                        0.2
#
#     Poverty gap at $3.20 a day (2011 PPP) (% of population)  \
# 67                                                2.7
# 73                                                3.6
# 76                                                2.2
#
#     Poverty gap at $5.50 a day (2011 PPP) (% of population)  \
# 67                                               14.9
# 73                                               17.3
# 76                                               12.4
#
#     Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)  \
# 67                                                1.1
# 73                                                2.0
# 76                                                1.1
#
#     Poverty headcount ratio at $1.90 a day, Female (2011 PPP) (% of female population)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, Male  (2011 PPP) (% of male population)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, age 0-14  (2011 PPP) (% of population age 0-14)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, age 15-64 (2011 PPP) (% of population age 15-64)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, age 65+ (2011 PPP) (% of population age 65+)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, rural (2011 PPP) (% of rural population)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, urban (2011 PPP) (% of urban population)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, with primary education (2011 PPP) (% of population age 16+ with primary education)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, with secondary education (2011 PPP) (% of population age 16+ with secondary education)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day, without education (2011 PPP) (% of population age 16+ without education)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $1.90 a day,  with Tertiary/post-secondary education (2011 PPP) (% of population age 16+ with Tertiary/post-secondary education)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)  \
# 67                                               13.9
# 73                                               17.0
# 76                                               10.9
#
#     Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)  \
# 67                                               51.5
# 73                                               54.1
# 76                                               42.6
#
#     Poverty headcount ratio at national poverty lines (% of population)  \
# 67                                                NaN
# 73                                               25.4
# 76                                               18.5
#
#     Poverty headcount ratio at national poverty lines (% of population), including noncomparable values  \
# 67                                                NaN
# 73                                               25.4
# 76                                               18.5
#
#     Redistribution component of change in poverty at $1.90 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Redistribution component of change in poverty at $3.20 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Redistribution component of change in poverty at $5.50 a day (2011 PPP) (% of change)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Survey mean consumption or income per capita, bottom 40% (2011 PPP $ per day)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Survey mean consumption or income per capita, top 10% (2011 PPP $ per day)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Survey mean consumption or income per capita, top 60% (2011 PPP $ per day)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#     Survey mean consumption or income per capita, total population (2011 PPP $ per day)  \
# 67                                                NaN
# 73                                                NaN
# 76                                                NaN
#
#    Short Name Table Name            Long Name 2-alpha code Currency Unit  \
# 67    Albania    Albania  Republic of Albania           AL  Albanian lek
# 73    Albania    Albania  Republic of Albania           AL  Albanian lek
# 76    Albania    Albania  Republic of Albania           AL  Albanian lek
#
#    Special Notes                 Region         Income Group WB-2 code  \
# 67           NaN  Europe & Central Asia  Upper middle income        AL
# 73           NaN  Europe & Central Asia  Upper middle income        AL
# 76           NaN  Europe & Central Asia  Upper middle income        AL
#
#                           National accounts base year  \
# 67  Original chained constant price data are resca...
# 73  Original chained constant price data are resca...
# 76  Original chained constant price data are resca...
#
#    National accounts reference year                SNA price valuation  \
# 67                             2010  Value added at basic prices (VAB)
# 73                             2010  Value added at basic prices (VAB)
# 76                             2010  Value added at basic prices (VAB)
#
#    Lending category Other groups  \
# 67             IBRD          NaN
# 73             IBRD          NaN
# 76             IBRD          NaN
#
#                           System of National Accounts  \
# 67  Country uses the 2008 System of National Accou...
# 73  Country uses the 2008 System of National Accou...
# 76  Country uses the 2008 System of National Accou...
#
#    Alternative conversion factor PPP survey year  \
# 67                           NaN         Rolling
# 73                           NaN         Rolling
# 76                           NaN         Rolling
#
#    Balance of Payments Manual in use External debt Reporting status  \
# 67                              BPM6                         Actual
# 73                              BPM6                         Actual
# 76                              BPM6                         Actual
#
#          System of trade    Government Accounting concept  \
# 67  Special trade system  Consolidated central government
# 73  Special trade system  Consolidated central government
# 76  Special trade system  Consolidated central government
#
#                       IMF data dissemination standard  \
# 67  Enhanced General Data Dissemination System (e-...
# 73  Enhanced General Data Dissemination System (e-...
# 76  Enhanced General Data Dissemination System (e-...
#
#    Latest population census                 Latest household survey  \
# 67                     2011  Demographic and Health Survey, 2017/18
# 73                     2011  Demographic and Health Survey, 2017/18
# 76                     2011  Demographic and Health Survey, 2017/18
#
#     Source of most recent Income and expenditure data  \
# 67  Living Standards Measurement Study Survey (LSM...
# 73  Living Standards Measurement Study Survey (LSM...
# 76  Living Standards Measurement Study Survey (LSM...
#
#    Vital registration complete Latest agricultural census  \
# 67                         Yes                       2012
# 73                         Yes                       2012
# 76                         Yes                       2012
#
#     Latest industrial data  Latest trade data  Unnamed: 30  is_country flag
# 67                  2013.0             2017.0          NaN        True   🇦🇱
# 73                  2013.0             2017.0          NaN        True   🇦🇱
# 76                  2013.0             2017.0          NaN        True   🇦🇱

# %%
poverty_data = pd.read_csv('../data/PovStatsData.csv')
poverty_data.head(3)
# Out:
#           Country Name Country Code  \
# 0  East Asia & Pacific          EAS
# 1  East Asia & Pacific          EAS
# 2  East Asia & Pacific          EAS
#
#                                       Indicator Name  Indicator Code  1974  \
# 0  Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 1  Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 2  Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
#
#    1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  1986  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2011  2012  2013  2014  2015  2016  2017  2018  2019  Unnamed: 50
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN

# %%
regions = ['East Asia & Pacific', 'Europe & Central Asia',
           'Fragile and conflict affected situations', 'High income',
           'IDA countries classified as fragile situations',
           'IDA total', 'Latin America & Caribbean', 'Low & middle income',
           'Low income', 'Lower middle income', 'Middle East & North Africa',
           'Middle income', 'South Asia', 'Sub-Saharan Africa',
           'Upper middle income', 'World']

# %%
population_df = poverty_data[~poverty_data['Country Name'].isin(regions) & 
                             (poverty_data['Indicator Name']== 'Population, total')]
population_df.head(3)
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1974  \
# 1051  Afghanistan          AFG  Population, total    SP.POP.TOTL  12412950.0
# 1115      Albania          ALB  Population, total    SP.POP.TOTL   2350124.0
# 1179      Algeria          DZA  Population, total    SP.POP.TOTL  16149025.0
#
#             1975        1976        1977        1978        1979        1980  \
# 1051  12689160.0  12943093.0  13171306.0  13341198.0  13411056.0  13356511.0
# 1115   2404831.0   2458526.0   2513546.0   2566266.0   2617832.0   2671997.0
# 1179  16607707.0  17085801.0  17582904.0  18102266.0  18647815.0  19221665.0
#
#             1981        1982        1983        1984        1985        1986  \
# 1051  13171673.0  12882528.0  12537730.0  12204292.0  11938208.0  11736179.0
# 1115   2726056.0   2784278.0   2843960.0   2904429.0   2964762.0   3022635.0
# 1179  19824301.0  20452902.0  21101875.0  21763575.0  22431502.0  23102389.0
#
#             1987        1988        1989        1990        1991        1992  \
# 1051  11604534.0  11618005.0  11868877.0  12412308.0  13299017.0  14485546.0
# 1115   3083605.0   3142336.0   3227943.0   3286542.0   3266790.0   3247039.0
# 1179  23774284.0  24443467.0  25106190.0  25758869.0  26400479.0  27028326.0
#
#             1993        1994        1995        1996        1997        1998  \
# 1051  15816603.0  17075727.0  18110657.0  18853437.0  19357126.0  19737765.0
# 1115   3227287.0   3207536.0   3187784.0   3168033.0   3148281.0   3128530.0
# 1179  27635515.0  28213774.0  28757785.0  29266405.0  29742979.0  30192754.0
#
#             1999        2000        2001        2002        2003        2004  \
# 1051  20170844.0  20779953.0  21606988.0  22600770.0  23680871.0  24726684.0
# 1115   3108778.0   3089027.0   3060173.0   3051010.0   3039616.0   3026939.0
# 1179  30623406.0  31042235.0  31451514.0  31855109.0  32264157.0  32692163.0
#
#             2005        2006        2007        2008        2009        2010  \
# 1051  25654277.0  26433049.0  27100536.0  27722276.0  28394813.0  29185507.0
# 1115   3011487.0   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0
# 1179  33149724.0  33641002.0  34166972.0  34730608.0  35333881.0  35977455.0
#
#             2011        2012        2013        2014        2015        2016  \
# 1051  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
# 1115   2905195.0   2900401.0   2895092.0   2889104.0   2880703.0   2876101.0
# 1179  36661444.0  37383887.0  38140132.0  38923687.0  39728025.0  40551404.0
#
#             2017        2018  2019  Unnamed: 50
# 1051  36296400.0  37172386.0   NaN          NaN
# 1115   2873457.0   2866376.0   NaN          NaN
# 1179  41389198.0  42228429.0   NaN          NaN

# %%
income_share_df = poverty.filter(regex='Country Name|^year$|Income share.*?20').dropna()
income_share_df = income_share_df.rename(columns={
    'Income share held by lowest 20%': '1 Income share held by lowest 20%',
    'Income share held by second 20%': '2 Income share held by second 20%',
    'Income share held by third 20%': '3 Income share held by third 20%',
    'Income share held by fourth 20%': '4 Income share held by fourth 20%',
    'Income share held by highest 20%': '5 Income share held by highest 20%'
}).sort_index(axis=1)


income_share_df.columns = [re.sub('\d Income share held by ', '', col).title()
                           for col in income_share_df.columns]
income_share_cols = income_share_df.columns[:-2]
income_share_df.head(3)
# Out:
#     Lowest 20%  Second 20%  Third 20%  Fourth 20%  Highest 20% Country Name  \
# 67         9.2        13.7       17.7        23.3         36.1      Albania
# 73         8.4        12.6       16.5        22.2         40.4      Albania
# 76         8.4        12.9       17.0        22.5         39.2      Albania
#
#     Year
# 67  1996
# 73  2002
# 76  2005

# %% [markdown]
# ## The Dashboard

# %%
app = dash.Dash(__name__,external_stylesheets=[dbc.themes.DARKLY])


categories = ['Region', 'Income Group']

app.layout = dbc.Container([
    html.H1('World Bank Poverty And Equity', style={'color': 'white','fontSize': '40px'}),
    html.Br(),
    html.H3('World Population',style={'color':'#000000','backgroundColor':'#ADD8E6','textAlign': 'center'}),
    html.Br(),
    dbc.Row(
        dbc.Col([
            dcc.Dropdown(id='year_dropdown',
#                                   value='2010',
                         options=[{'label': year, 'value': str(year)} 
                                           for year in range(1974, 2019)],
                         placeholder='Select Year',
                         style = dict(color='#000000')
                                 ),
            html.Br(),
            dcc.Graph(id='population_chart')       
                ])
            ),
    html.Br(),
    html.H3('Gini Index - World Bank Data', 
            style={'color':'#000000','backgroundColor':'#ADD8E6','textAlign': 'center'}),
    html.H6("""Gini index measures the extent to which the distribution 
                of income (or, in some cases, consumption expenditure) 
                among individuals or households within an economy 
                deviates from a perfectly equal distribution. A Lorenz 
                curve plots the cumulative percentages of total income 
                received against the cumulative number of recipients, 
                starting with the poorest individual or household. The 
                Gini index measures the area between the Lorenz curve 
                and a hypothetical line of absolute equality, expressed 
                as a percentage of the maximum area under the line. Thus 
                a Gini index of 0 represents perfect equality, while an 
                index of 100 implies perfect inequality."""),
    html.Br(),
    dbc.Row([
        dbc.Col([
            dcc.Dropdown(id='gini_year_dropdown',
                         options=[{'label': y, 'value': y} 
                                  for y in gini_df['year'].drop_duplicates().sort_values()],
                         placeholder='Select Year',
                         style = dict(color='#000000',backgroundColor='#ADD8E6')
                        ),
            html.Br(),
            dcc.Graph(id='gini_year_barchart')
        ]),
        dbc.Col([
            dcc.Dropdown(id='gini_country_dropdown',
                         multi=True,
                         options=[{'label': country, 'value': country} for 
                                  country in gini_df['Country Name'].unique()],
                        placeholder='Select Country',
                        style = dict(color='#000000',backgroundColor='#ADD8E6')
                        ),
            html.Br(),
            dcc.Graph(id='gini_country_barchart')
        ]),
    ]),
    html.Br(),
    html.H3('Income Share Distribution', style={'color':'#000000','backgroundColor':'#ADD8E6','textAlign': 'center'}),
    html.Br(),
    dbc.Row(dbc.Col([
            dcc.Dropdown(id='income_share_country_dropdown', 
                         options=[{'label': country, 'value': country}
                                   for country in income_share_df['Country Name'].unique()],
                        placeholder='Select Country',
                        style = dict(color='#000000',backgroundColor='#ADD8E6')
                        ),
            html.Br(),
            dcc.Graph(id='income_share_country_barchart')   
                     
                    ])
           ),
    dbc.Tabs([
          dbc.Tab([
            html.Ul([
                html.Br(),
                html.Li(
                        [
                        'Author:  ',
                         html.A('Waleed',href='https://www.linkedin.com/in/waleedabdulla/')
                        ]
                       ),
                html.Li('Job Title: Data Analyst (actively looking for work)'),
                html.Li(['LinkedIn: ', 
                             html.A('Waleed on LinkedIn',         
                             href='https://github.com/Waleed18574/Waleed_Python_Data_Analysis_and_Data_Science_Portfolio_Projects')
                            ]),
                html.Li(['GitHub: ', 
                             html.A('Waleed on Github',         
                             href='https://www.linkedin.com/in/waleedabdulla/')
                            ]),
                html.Br(),
                html.Br()
                    ]
                   )
                 ], 
            label='Author Info'),
          dbc.Tab([
           html.Ul([html.Li(['Data Source: ', 
                             html.A('World Bank Poverty & Equity Dataset',         
                             href='https://datacatalog.worldbank.org/dataset/poverty-and-equity-database')
                            ]),
                    html.Li('Number of Economies: 170'),
                    html.Li('Temporal Coverage: 1974 - 2019'),
                    html.Li('Update Frequency: Quarterly'),
                    html.Li('Last Updated: March 18, 2020')
                    
                    ]
                   ),
                  ], 
            label='Project Key Facts'
                  )
            ] 
           )
    ], style = {'backgroundColor':'#000000'})


@app.callback(Output('population_chart', 'figure'),
              [Input('year_dropdown', 'value')])
def plot_countries_by_population(year):
    if not year:
        raise PreventUpdate
    fig = go.Figure()
    year_df = population_df[['Country Name', year]].sort_values(year, ascending=False)[:20]
    fig.add_bar(x=year_df['Country Name'], y=year_df[year])
    fig.layout.title = f'Top twenty countries by population - {year}'
    fig.layout.template='plotly_dark'
    return fig


@app.callback(Output('gini_year_barchart', 'figure'),
              Input('gini_year_dropdown', 'value'))
def plot_gini_year_barchart(year):
    if not year:
        raise PreventUpdate
    df = gini_df[gini_df['year'].eq(year)].sort_values(gini).dropna(subset=[gini])
    n_countries = len(df['Country Name'])
    fig = px.bar(df,
                 x=gini,
                 y='Country Name', 
                 orientation='h',
                 template='plotly_dark',
                 height=200 + (n_countries*20), 
                 title=gini + ' ' + str(year))
    return fig


@app.callback(Output('gini_country_barchart', 'figure'),
              Input('gini_country_dropdown', 'value'))
def plot_gini_country_barchart(countries):
    if not countries:
        raise PreventUpdate
    df = gini_df[gini_df['Country Name'].isin(countries)].dropna(subset=[gini])
    fig = px.bar(df,
                 x=gini,
                 y='year', 
                 orientation='h',
                 height=100 + (250*len(countries)),
                 labels={gini: 'Gini Index'},
                 template='plotly_dark',
                 color='Country Name',
                 title=''.join([gini, '<br>', '<b>',', '.join(countries), '</b>']))
    return fig

@app.callback(Output('income_share_country_barchart', 'figure'),
              Input('income_share_country_dropdown', 'value'))
def plot_income_share_barchart(country):
    if country is None:
        raise PreventUpdate
    fig = px.bar(income_share_df[income_share_df['Country Name']==country].dropna(), 
                 x=income_share_cols,
                 y='Year',
                 barmode='stack',
                 height=600, 
                 hover_name='Country Name',
                 title=f'Income Share Quintiles - {country}',
                 template='plotly_dark',
                 orientation='h')
    fig.layout.legend.title = None
    fig.layout.legend.orientation = 'h'
    fig.layout.legend.x = 0.2
    fig.layout.xaxis.title = 'Percent of Total Income'
    return fig


app.run_server(debug=False, )
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2022 14:20:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/deps/react@16.v2_4_1m1653999597.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_4_1m1653999597.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_4_1m1653999597.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_4_1m1653999597.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_4_1m1653999596.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_4_0m1653999596.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:43] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_4_0m1653999596.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_2m1653999596.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_3m1653999597.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_favicon.ico?v=2.4.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [31/May/2022 14:20:44] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [31/May/2022 14:20:48] "POST /_dash-update-component HTTP/1.1" 200 -
